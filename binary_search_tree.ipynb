# %% [markdown]
# <a href="https://colab.research.google.com/github/MerveDemirden/Patika.dev-Python_Projeleri/blob/main/binary_search_tree.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Binary Search Tree Projesi**
#
# **Proje 3**
#
# [7, 5, 1, 8, 3, 6, 0, 9, 4, 2] -> Merge Sort
#
# Örnek: root x'dir. root'un sağından y bulunur. Solunda z bulunur vb.

# %% [markdown]
# root = 7
#
#                         7
# *   5 < 7  ▶ sol
#
#                        7
#                       /
#                      5
# *   1 < 7  ▶ sol
#
#     1 < 5  ▶ sol
#                       7
#                      /
#                     5
#                   /
#                  1
#
# *   8 > 7  ▶ sağ
#
#                     7
#                    / \
#                   5   8
#                  /
#                 1
#
# *   3 < 7  ▶ sol
#
# *   3 > 5  ▶ sol
#
# *   3 > 1  ▶ sağ
#
#                     7
#                    / \
#                   5   8
#                  /
#                 1
#                  \
#                   3
#
# *  6 < 7 ▶ sol
# *  6 > 5 ▶ sağ
#
#                     7
#                    / \
#                   5   8
#                  / \
#                 1   6
#                  \
#                   3
#
# *  0 < 7 ▶ sol
# *  0 < 5 ▶ sol
# *  0 < 1 ▶ sol
#
#                     7
#                    / \
#                   5   8
#                  / \
#                 1   6
#                / \
#               0   3
#
# *  9 > 7 ▶ sağ
# *  9 > 8 ▶ sağ
#                      7
#                    /  \
#                   5    8
#                  / \    \
#                 1   6    9
#                / \
#               0   3
#
# *  4 < 7 ▶ sol
# *  4 < 5 ▶ sol
# *  4 > 1 ▶ sağ
# *  4 > 3 ▶ sağ
#                     7
#                    /  \
#                   5    8
#                  / \    \
#                 1   6    9
#                / \
#               0   3
#                    \
#                     4
#
# *  2 < 7 ▶ sol
# *  2 < 7 ▶ sol
# *  2 > 1 ▶ sağ
# *  2 < 3 ▶ sol
#
#                     7
#                    /  \
#                   5    8
#                  / \    \
#                 1   6    9
#                / \
#               0   3
#                  /  \
#                 2    4
